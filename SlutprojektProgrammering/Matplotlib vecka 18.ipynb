# %%
import pandas as pd
import matplotlib.pyplot as plt

pokemon_df = pd.read_csv(r"C:\Users\hassan\Desktop\SlutprojektProgrammering\pokemondata.csv")

plt.bar(pokemon_df["Name"][:10], pokemon_df["Attack"][:10])

plt.title("Top 10 Pokémon med högst attackpoäng")
plt.xlabel("Pokémon")
plt.ylabel("Attackpoäng")

plt.show()
